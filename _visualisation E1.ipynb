# %%
import pandas as pd
import seaborn as sns

# %%
co2=pd.read_csv('CO2_emission.csv')
co2.head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
# 3  CO2 emissions (metric tons per capita)  1.819542  1.242810  0.683700
# 4  CO2 emissions (metric tons per capita)  7.521832  7.235379  6.963079
#
#        1993      1994      1995  ...      2011      2012      2013      2014  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
co2.dropna(inplace=True) 
co2
# Out:
#              Country Name country_code                      Region  \
# 1             Afghanistan          AFG                  South Asia
# 2                  Angola          AGO          Sub-Saharan Africa
# 3                 Albania          ALB       Europe & Central Asia
# 4                 Andorra          AND       Europe & Central Asia
# 5    United Arab Emirates          ARE  Middle East & North Africa
# ..                    ...          ...                         ...
# 210                 Samoa          WSM         East Asia & Pacific
# 211           Yemen, Rep.          YEM  Middle East & North Africa
# 212          South Africa          ZAF          Sub-Saharan Africa
# 213                Zambia          ZMB          Sub-Saharan Africa
# 214              Zimbabwe          ZWE          Sub-Saharan Africa
#
#                              Indicator Name       1990       1991       1992  \
# 1    CO2 emissions (metric tons per capita)   0.191745   0.167682   0.095958
# ...

# %%
co2.head()
# Out:
#            Country Name country_code                      Region  \
# 1           Afghanistan          AFG                  South Asia
# 2                Angola          AGO          Sub-Saharan Africa
# 3               Albania          ALB       Europe & Central Asia
# 4               Andorra          AND       Europe & Central Asia
# 5  United Arab Emirates          ARE  Middle East & North Africa
#
#                            Indicator Name       1990       1991       1992  \
# 1  CO2 emissions (metric tons per capita)   0.191745   0.167682   0.095958
# 2  CO2 emissions (metric tons per capita)   0.553662   0.544539   0.543557
# 3  CO2 emissions (metric tons per capita)   1.819542   1.242810   0.683700
# 4  CO2 emissions (metric tons per capita)   7.521832   7.235379   6.963079
# 5  CO2 emissions (metric tons per capita)  30.195189  31.778496  29.080926
#
#         1993       1994       1995  ...       2011       2012       2013  \
# ...

# %%
sns.distplot(co2['1990'],color='r')
# Out:
# C:\Users\2211582\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='1990', ylabel='Density'>

# %% [markdown]
# The year 1990 follows the right skewed with positive kurtose

# %%
sns.boxplot(data=co2,x='2012',color='y')
# Out:
# <AxesSubplot:xlabel='2012'>

# %%
sns.histplot(x='1998',data=co2)
# Out:
# <AxesSubplot:xlabel='1998', ylabel='Count'>

# %%
Bc=pd.read_csv('https://raw.githubusercontent.com/a-forty-two/CGI-DPplusPy/main/breastcancer_data.csv')
Bc
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0       842302         M        17.99         10.38          122.80
# 1       842517         M        20.57         17.77          132.90
# 2     84300903         M        19.69         21.25          130.00
# 3     84348301         M        11.42         20.38           77.58
# 4     84358402         M        20.29         14.34          135.10
# ...        ...       ...          ...           ...             ...
# 1133     93316         M        21.56         22.39          142.00
# 1134     93317         M        20.13         28.25          131.20
# 1135     93318         M        16.60         28.08          108.30
# 1136     93319         M        20.60         29.33          140.10
# 1137     93320         B         7.76         24.54           47.92
#
#       area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0        1001.0          0.11840           0.27760         0.30010
# ...

# %%
da=Bc.head()
da
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  symmetry_mean  \
# 0          0.11840           0.27760          0.3001         0.2419
# 1          0.08474           0.07864          0.0869         0.1812
# 2          0.10960           0.15990          0.1974         0.2069
# 3          0.14250           0.28390          0.2414         0.2597
# 4          0.10030           0.13280          0.1980         0.1809
#
#    fractal_dimension_mean
# 0                 0.07871
# 1                 0.05667
# ...

# %%
Bc.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  1.138000e+03  1138.000000   1138.000000     1138.000000  1138.000000
# mean   1.523243e+07    14.127292     19.289649       91.969033   654.889104
# std    8.965268e+07     3.522499      4.299144       24.288293   351.759340
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    9.299525e+04    11.700000     16.170000       75.170000   420.300000
# 50%    9.327950e+04    13.370000     18.840000       86.240000   551.100000
# 75%    9.060125e+05    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  symmetry_mean  \
# count      1138.000000       1138.000000     1138.000000    1138.000000
# mean          0.096360          0.104341        0.088799       0.181162
# ...

# %%
Bc.isna()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     False      False        False         False           False      False
# 1     False      False        False         False           False      False
# 2     False      False        False         False           False      False
# 3     False      False        False         False           False      False
# 4     False      False        False         False           False      False
# ...     ...        ...          ...           ...             ...        ...
# 1133  False      False        False         False           False      False
# 1134  False      False        False         False           False      False
# 1135  False      False        False         False           False      False
# 1136  False      False        False         False           False      False
# 1137  False      False        False         False           False      False
#
# ...

# %%
sns.heatmap(Bc.isnull(),cbar = False, yticklabels = False,cmap = 'Spectral')
# Out:
# <AxesSubplot:>

# %% [markdown]
# since there is no blank space the dataset has no nullvalues in it.

# %%
sns.distplot(Bc['concavity_mean'],color='r')
# Out:
# C:\Users\2211582\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='concavity_mean', ylabel='Density'>

# %% [markdown]
# The concavity mean is skewed right.

# %%
sns.histplot(x='symmetry_mean',color='g',data=Bc)
# Out:
# <AxesSubplot:xlabel='symmetry_mean', ylabel='Count'>

# %%
Bc['symmetry_mean'].mean()
# Out:
# 0.18116186291739897

# %% [markdown]
# The symmetry mean lies slightly towards left.

# %%
sns.barplot(data=da,x='area_mean',y='perimeter_mean')
# Out:
# <AxesSubplot:xlabel='area_mean', ylabel='perimeter_mean'>

# %%
sns.violinplot(data=Bc,x='diagnosis',y='smoothness_mean',palette='BuPu')
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='smoothness_mean'>

# %%
sns.boxplot(data=Bc,x='diagnosis',y='concavity_mean',palette='flare')
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='concavity_mean'>

# %% [markdown]
# under diagnosis the concavity mean of 'B'  is below 0.1 with outliers  whereas the concavity mean of 'M' is above the 0.1 with less outliers.

# %%
sns.scatterplot(data=Bc,x='area_mean',y='smoothness_mean',palette='flag')
# Out:
# <AxesSubplot:xlabel='area_mean', ylabel='smoothness_mean'>

# %%
sns.stripplot(data=Bc,x='texture_mean',y='smoothness_mean')
# Out:
# <AxesSubplot:xlabel='texture_mean', ylabel='smoothness_mean'>

# %%
sns.jointplot(data=Bc,x='compactness_mean',y='smoothness_mean',kind='reg')

# %%
sns.pairplot(data=Bc,hue='diagnosis',palette='bone')

# %%
sns.heatmap(Bc.corr(),cmap = 'crest',annot = True)
# Out:
# <AxesSubplot:>
